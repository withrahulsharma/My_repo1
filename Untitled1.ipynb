# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data=pd.read_csv("Datasets/Housing_price_advanced/train.csv")

# %%
data["MSZoning"].head()
columns=data.columns
print(data._get_numeric_data().columns)
print([i for i in columns if i not in data._get_numeric_data().columns])
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')
# ...

# %%
sns.barplot(x='LotShape',y="SalePrice",data=data,hue="RoofMatl")

# %%
data.corr()
sns.jointplot(x="LotArea",y="SalePrice",data=data,kind="reg")

# %%
sns.distplot(data["YrSold"],bins=10)
print(data["YrSold"].isnull().sum())
# Out:
# 0

# %%
sns.boxplot(x="Electrical",y="SalePrice",data=data,color="b")
